# %% [markdown]
# <a href="https://colab.research.google.com/github/dhruvbit/fundamentals/blob/main/pract1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_list=[22,39,13,53]
max =  0
for number in my_list:
  if number > max:
      max = number


print(max)
# Out:
# 53

# %%
movie_list = ["pulp fiction","inception","kill bill","doomsday","doomsday","pulp fiction"]
unquie_list = []
for movie in movie_list:
  if movie not in unquie_list:
    unquie_list.append(movie)

print(unquie_list)
# Out:
# ['pulp fiction', 'inception', 'kill bill', 'doomsday']
